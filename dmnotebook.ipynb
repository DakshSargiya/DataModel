# %%
import psycopg2
import pandas as pd

# %%
try: 
    conn = psycopg2.connect("host=127.0.0.1 dbname=postgres user=postgres password=root")
except psycopg2.Error as e: 
    print("Error: Could not make connection to the Postgres database")
    print(e)
    
try: 
    cur = conn.cursor()
except psycopg2.Error as e: 
    print("Error: Could not get curser to the Database")
    print(e)
    
conn.set_session(autocommit=True)

try: 
    cur.execute("create database wealthData")
except psycopg2.Error as e:
    print(e)
# Out:
# database "wealthdata" already exists

# %%
try: 
    conn.close()
except psycopg2.Error as e:
    print(e)
    
try: 
    conn = psycopg2.connect("host=127.0.0.1 dbname=wealthdata user=postgres password=root")
except psycopg2.Error as e: 
    print("Error: Could not make connection to the Postgres database")
    print(e)
    
try: 
    cur = conn.cursor()
except psycopg2.Error as e: 
    print("Error: Could not get curser to the Database")
    print(e)

conn.set_session(autocommit=True)

# %%
def drop_tables(cur, conn):
    for query in drop_table_queries:
        cur.execute(query)
        conn.commit()
def create_tables(cur, conn):
    for query in create_table_queries:
        cur.execute(query)
        conn.commit()

# %%
AccountsCountry = pd.read_csv("Wealth-AccountsCountry.csv")
AccountsData = pd.read_csv("Wealth-AccountData.csv")
AccountsSeries = pd.read_csv("Wealth-AccountSeries.csv")

# %%
AccountsCountry.head()
# Out:
#   Code                  Long Name         Income Group  \
# 0  ALB        Republic of Albania  Upper middle income
# 1  ARG         Argentine Republic  Upper middle income
# 2  ARM        Republic of Armenia  Upper middle income
# 3  AUS  Commonwealth of Australia          High income
# 4  AUT        Republic of Austria          High income
#
#                       Region Lending category Other groups      Currency Unit  \
# 0      Europe & Central Asia             IBRD          NaN       Albanian lek
# 1  Latin America & Caribbean             IBRD          NaN     Argentine peso
# 2      Europe & Central Asia             IBRD          NaN      Armenian dram
# 3        East Asia & Pacific              NaN          NaN  Australian dollar
# 4      Europe & Central Asia              NaN    Euro area               Euro
#
#                             Latest population census  \
# 0                                    2020 (expected)
# 1                                    2020 (expected)
# ...

# %%
AccountsCountryClean = AccountsCountry[['Code', 'Long Name','Currency Unit', 'Table Name', 'Short Name']][:146]

# %%
AccountsCountryClean.head()
# Out:
#   Code                  Long Name      Currency Unit Table Name Short Name
# 0  ALB        Republic of Albania       Albanian lek    Albania    Albania
# 1  ARG         Argentine Republic     Argentine peso  Argentina  Argentina
# 2  ARM        Republic of Armenia      Armenian dram    Armenia    Armenia
# 3  AUS  Commonwealth of Australia  Australian dollar  Australia  Australia
# 4  AUT        Republic of Austria               Euro    Austria    Austria

# %%
AccountsData.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999]  \
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10      4.22E+10
# 1      14072.79      13708.99       11794.1      12399.48      13573.26
# 2      3468.858      3355.549      2868.997      3013.391      3259.893
# 3      6507.931      6353.737      5466.692      5901.072       6492.73
# ...

# %%
AccountsData = AccountsData.drop(['2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'], axis=1)

# %%
AccountsSeries.head()
# Out:
#              Code                                     Indicator Name  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition  \
# 0  Human capital is computed as the present value...
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic  \
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# ...

# %%
AccountsSeriesClean = AccountsSeries[['Code', 'Indicator Name', 'Long definition', 'Source', 'Topic']]

# %%
AccountsSeriesClean.head()
# Out:
#              Code                                     Indicator Name  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition  \
# 0  Human capital is computed as the present value...
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# ...

# %%
accounts_country_table_create = ("""CREATE TABLE IF NOT EXISTS accscountry(
country_code VARCHAR PRIMARY KEY, 
long_name VARCHAR,
currency_unit VARCHAR,
table_name VARCHAR,
short_name VARCHAR
)""")
cur.execute(accounts_country_table_create)
conn.commit()

# %%
accounts_data_table_create = ("""CREATE TABLE IF NOT EXISTS accsdata(
country_name VARCHAR, country_code VARCHAR, series_name VARCHAR, series_code VARCHAR,
       YR1995 VARCHAR, YR1996 VARCHAR, YR1997 VARCHAR, YR1998 VARCHAR,
       YR1999 VARCHAR, YR2000 VARCHAR, YR2001 VARCHAR, YR2002 VARCHAR,
       YR2003 VARCHAR, YR2004 VARCHAR, YR2005 VARCHAR, YR2006 VARCHAR,
       YR2007 VARCHAR, YR2008 VARCHAR, YR2009 VARCHAR, YR2010 VARCHAR,
       YR2011 VARCHAR, YR2012 VARCHAR, YR2013 VARCHAR, YR2014 VARCHAR,
       YR2015 VARCHAR
)""")
cur.execute(accounts_data_table_create)
conn.commit()

# %%
accounts_series_table_create = ("""CREATE TABLE IF NOT EXISTS accsseries(
series_code VARCHAR, 
indicator_name VARCHAR,
long_definition VARCHAR,
source VARCHAR,
topic VARCHAR
)""")
cur.execute(accounts_series_table_create)
conn.commit()

# %%
acc_cont_table_insert = ("""INSERT INTO accscountry(
country_code, 
long_name,
currency_unit,
table_name,
short_name)
VALUES(%s, %s, %s, %s, %s)
""")

# %%
for i, row in AccountsCountryClean.iterrows():
    cur.execute(acc_cont_table_insert, list(row))

# %%
acc_data_table_insert = ("""INSERT INTO accsdata(
country_name, country_code, series_name, series_code,
       YR1995, YR1996, YR1997, YR1998,
       YR1999, YR2000, YR2001, YR2002,
       YR2003, YR2004, YR2005, YR2006,
       YR2007, YR2008, YR2009, YR2010,
       YR2011, YR2012, YR2013, YR2014,
       YR2015)
VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
""")

# %%
for i, row in AccountsData.iterrows():
    cur.execute(acc_data_table_insert, list(row))

# %%
acc_series_table_insert = ("""INSERT INTO accsseries(
series_code, 
indicator_name,
long_definition,
source,
topic)
VALUES(%s, %s, %s, %s, %s)
""")

# %%
for i, row in AccountsSeriesClean.iterrows():
    cur.execute(acc_series_table_insert, list(row))
